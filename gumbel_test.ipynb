# %%
from scipy.stats import gumbel_r
import matplotlib.pyplot as plt

# %%
env_knowledge_chance = gumbel_r.rvs(loc = 0, scale = 1, size = 10000)

print(env_knowledge_chance)

plt.hist(env_knowledge_chance, bins = 30, density = True)
plt.axvline(-1, color = 'g')
plt.axvline(1, color = 'g')
# Out:
# [ 0.55353297 -0.46975881  0.08310081 ...  1.28644524 -1.44350953
#  -0.52295216]
